# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Project/Dataset/laptop_price.csv',encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample()
# Out:
#     Company                              Product  TypeName  Inches  \
# 450      HP  15-bs024nv (i5-7200U/8GB/128GB/W10)  Notebook    15.6
#
#     ScreenResolution                         Cpu  Ram     Memory  \
# 450         1366x768  Intel Core i5 7200U 2.5GHz  8GB  128GB SSD
#
#                        Gpu       OpSys  Weight  Price_euros
# 450  Intel HD Graphics 620  Windows 10  1.91kg        589.0

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1275, 12)

# %%
df['Price_euros']
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
#          ...
# 1270     638.00
# 1271    1499.00
# 1272     229.00
# 1273     764.00
# 1274     369.00
# Name: Price_euros, Length: 1275, dtype: float64

# %%
round(df['Price_euros']*93.73).astype('int')
# Out:
# 0       125569
# 1        84258
# 2        53895
# 3       237835
# 4       169051
#          ...
# 1270     59800
# 1271    140501
# 1272     21464
# 1273     71610
# 1274     34586
# Name: Price_euros, Length: 1275, dtype: int64

# %%
df['Price']=round(df['Price_euros']*93.73).astype('int')
df.drop(columns=['Price_euros'],inplace=True)
df.sample()
# Out:
#      Company      Product TypeName  Inches   ScreenResolution  \
# 1259     MSI  GE62 Apache   Gaming    15.6  Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 1259  Intel Core i7 6700HQ 2.6GHz  8GB  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys Weight   Price
# 1259  Nvidia GeForce GTX 960M  Windows 10  2.4kg  115194

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Company'].value_counts().index,y=df['Company'].value_counts())
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
ndf=df[df.groupby('Company').Company.transform('count')>10].copy()
ndf['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
ndf
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
sns.barplot(x=ndf['Company'].value_counts().index,y=ndf['Company'].value_counts(),width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('Company').count()
# Out:
#            Product  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  Gpu  \
# Company
# Acer           101       101     101               101  101  101     101  101
# Apple           21        21      21                21   21   21      21   21
# Asus           152       152     152               152  152  152     152  152
# Chuwi            3         3       3                 3    3    3       3    3
# Dell           291       291     291               291  291  291     291  291
# Fujitsu          3         3       3                 3    3    3       3    3
# Google           3         3       3                 3    3    3       3    3
# HP             268       268     268               268  268  268     268  268
# Huawei           2         2       2                 2    2    2       2    2
# LG               3         3       3                 3    3    3       3    3
# Lenovo         289       289     289               289  289  289     289  289
# ...

# %%
df.groupby('Company').Company.transform('count')
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
df.groupby('Company').sum()
# Out:
#                                                      Product  \
# Company
# Acer       Aspire 3Swift 3Aspire 3Aspire A515-51GAspire A...
# Apple      MacBook ProMacbook AirMacBook ProMacBook ProMa...
# Asus       ZenBook UX430UNVivobook E200HAE402WA-GA010T (E...
# Chuwi                  LapBook 15.6"LapBook 12.3Lapbook 15,6
# Dell       Inspiron 3567Inspiron 3567XPS 13Inspiron 5379I...
# Fujitsu              Lifebook A557LifeBook A557LifeBook A556
# Google         Pixelbook (CorePixelbook (CorePixelbook (Core
# HP         250 G6250 G6250 G6255 G615-BS101nv (i7-8550U/8...
# Huawei                                  MateBook XMateBook X
# LG                         Gram 15Z975Gram 15Z970Gram 14Z970
# Lenovo     IdeaPad 320-15IKBLegion Y520-15IKBNIdeaPad 120...
# MSI        GS73VR 7RGGL72M 7RDXGP62M 7REXGS63VR 7RGGE72MV...
# Mediacom   FlexBook EdgeSmartBook EdgeSmartBook 130SmartB...
# Microsoft  Surface LaptopSurface LaptopSurface LaptopSurf...
# ...

# %%
df.groupby('Company').sum('int')
# Out:
#            Inches     Price
# Company
# Acer       1520.3   5996840
# Apple       278.2   3078858
# Asus       2352.1  16011155
# Chuwi        43.5     88377
# Dell       4401.8  32709376
# Fujitsu      46.8    204987
# Google       36.9    471743
# HP         4008.8  27137105
# Huawei       26.0    266943
# LG           45.2    590217
# Lenovo     4303.4  29630499
# MSI         887.9   8750727
# Mediacom     94.2    193551
# Microsoft    81.0    906730
# Razer       101.6   2195436
# Samsung     124.4   1192338
# Toshiba     689.0   5703937
# Vero         55.3     81517
# Xiaomi       57.8    424958

# %%
df.groupby('Company').mean('int')['Price']
# Out:
# Company
# Acer          59374.653465
# Apple        146612.285714
# Asus         105336.546053
# Chuwi         29459.000000
# Dell         112403.353952
# Fujitsu       68329.000000
# Google       157247.666667
# HP           101257.854478
# Huawei       133471.500000
# LG           196739.000000
# Lenovo       102527.678201
# MSI          162050.500000
# Mediacom      27650.142857
# Microsoft    151121.666667
# Razer        313633.714286
# Samsung      132482.000000
# Toshiba      118832.020833
# Vero          20379.250000
# Xiaomi       106239.500000
# Name: Price, dtype: float64

# %%
df=df[df.groupby('Company').Company.transform('count')>10].copy()
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.barplot(x=df['Inches'],y=df['Price'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(df['Inches'],kde=True)

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
a='IPS Panel Touchscreen / 4K Ultra HD 3840x2160'
a.split() #['IPS', 'Panel', 'Touchscreen', '/', '4K', 'Ultra', 'HD', '3840x2160']
a.split()[-1].split('x') #['3840','2160']
a.split()[-1].split('x')[0] #'3840'
a.split()[-1].split('x')[1] #'2160'
# Out:
# '2160'

# %%
df['ScreenResolution'].count()
# Out:
# 1224

# %%
(lambda x:x.split()[-1].split('x')[0])('IPS Panel Touchscreen / 4K Ultra HD 3840x2160	')
# Out:
# '3840'

# %%
df['xres']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[0]).astype('int')

# %%
df['yres']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[1]).astype('int')

# %%
df.sample()
# Out:
#     Company            TypeName  Inches      ScreenResolution  \
# 314    Asus  2 in 1 Convertible    11.6  Touchscreen 1366x768
#
#                                       Cpu  Ram              Memory  \
# 314  Intel Celeron Dual Core N3350 1.1GHz  2GB  32GB Flash Storage
#
#                        Gpu       OpSys Weight  Price  xres  yres
# 314  Intel HD Graphics 500  Windows 10  1.1kg  25776  1366   768

# %%
(lambda x:1 if 'Touchscreen' in x else 0)('IPS Panel Touchscreen / 4K Ultra HD 3840x2160')
# Out:
# 1

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches ScreenResolution                         Cpu  \
# 1003      HP  Notebook    14.0         1366x768  Intel Core i5 7200U 2.5GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight  Price  xres  \
# 1003  4GB  500GB HDD  Intel HD Graphics 620  Windows 10  1.64kg  73016  1366
#
#       yres  Touchscreen  IPS
# 1003   768            0    0

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
a='Intel Core i5 7200U 2.5GHz'
a.split() #['Intel', 'Core', 'i5', '7200U', '2.5GHz']
a.split()[0] #'Intel'
a.split()[1] #'Core'
a.split()[2] #'i5'
# Out:
# 'i5'

# %%
' '.join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda x:' '.join(x.split()[0:3]))(a)
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# ...

# %%
plt.figure(figsize=(14,4))
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# ...

# %%
def fetch_processor(text):
  if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3' or text=='Intel Core M' :
    return ' '.join(text.split()[0:3])
  elif text.split()[0]=='Intel':
    return ' '.join(text.split()[0:2])
  else:
    return 'AMD processor'

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7    493
# Intel Core i5    411
# Intel Core i3    134
# Intel Celeron     71
# AMD processor     60
# Intel Pentium     30
# Intel Core M      16
# Intel Atom         5
# Intel Xeon         4
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Cpu'].value_counts().index,y=df['Cpu'].value_counts())
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Cpu'],y=df['Price'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace('GB','')).astype('int')

# %%
df['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1270     4
# 1271    16
# 1272     2
# 1273     6
# 1274     4
# Name: Ram, Length: 1224, dtype: int64

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Ram'],y=df['Price'],width=0.5)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram                    Gpu  \
# 522    Dell  Notebook    14.0  Intel Core i5    8  Intel HD Graphics 620
#
#           OpSys  Weight   Price  xres  yres  Touchscreen  IPS
# 522  Windows 10  1.64kg  119949  1920  1080            0    0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     666
# Nvidia    385
# AMD       173
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
df['Gpu'].value_counts().plot(kind='bar',width=0.4)
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],width=0.5)
plt.xticks(rotation=0)
plt.show()

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram    Gpu       OpSys Weight  \
# 765    Acer  Notebook    13.3  Intel Core i5    4  Intel  Windows 10  1.6kg
#
#      Price  xres  yres  Touchscreen  IPS
# 765  61393  1366   768            0    0

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def fetch_os(text):
  if text=='Windows 10' or text=='Windows 10 S':
    return 'Windows 10'
  elif text=='Windows 7':
    return text
  elif text=='Mac OS X' or text=='macOS':
    return 'MacOS'
  else:
    return 'Linux/No OS/Others'

# %%
df['OpSys']=df['OpSys'].apply(fetch_os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10            1013
# Linux/No OS/Others     145
# Windows 7               45
# MacOS                   21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     115
# 2.1kg      58
# 2.4kg      42
# 2.5kg      37
# 2.3kg      36
#          ...
# 1.71kg      1
# 0.98kg      1
# 4.7kg       1
# 1.55kg      1
# 4.0kg       1
# Name: count, Length: 175, dtype: int64

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace('kg','')).astype('float')

# %%
sns.displot(df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
plt.show()

# %%
plt.figure(figsize=(3,5))
df['Touchscreen'].value_counts().plot(kind='bar',width=0.4)
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'],width=0.5)
plt.show()

# %%
df['IPS'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(x=df['IPS'],y=df['Price'],width=0.5)
plt.show()

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# xres           0.553707
# yres           0.552963
# Touchscreen    0.161443
# IPS            0.289225
# Name: Price, dtype: float64

# %%
df.corr(numeric_only=True)['Price'].sort_values(ascending=False)
# Out:
# Price          1.000000
# Ram            0.726639
# xres           0.553707
# yres           0.552963
# IPS            0.289225
# Weight         0.212038
# Touchscreen    0.161443
# Inches         0.055330
# Name: Price, dtype: float64

# %%
df['PPI']=round((((df['xres']**2)+(df['yres']**2))**0.5/df['Inches'])).astype('int')

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches            Cpu  Ram     Gpu       OpSys  \
# 1001      HP   Notebook    13.3  Intel Core i5    8   Intel  Windows 10
# 295   Lenovo     Gaming    15.6  Intel Core i7    8  Nvidia  Windows 10
# 460     Acer   Notebook    15.6  Intel Core i3    4  Nvidia  Windows 10
# 396   Lenovo   Notebook    15.6  Intel Core i7    8     AMD  Windows 10
# 336     Dell  Ultrabook    15.6  Intel Core i5    8  Nvidia  Windows 10
#
#       Weight   Price  xres  yres  Touchscreen  IPS  PPI
# 1001    1.34  111445  1920  1080            0    1  166
# 295     3.20  121755  1920  1080            0    1  141
# 460     2.23   50989  1920  1080            0    0  141
# 396     2.10  115247  1920  1080            0    1  141
# 336     1.90   98323  1920  1080            0    1  141

# %%
df['PPI'].value_counts()
# Out:
# PPI
# 141    419
# 100    195
# 127    131
# 157    122
# 166    100
# 112     42
# 135     28
# 176     25
# 276     25
# 282     23
# 106     22
# 210     18
# 125      9
# 118      8
# 331      7
# 227      6
# 226      6
# 221      6
# 255      5
# 128      4
# 224      4
# 158      4
# 317      2
# 170      2
# 91       2
# 352      2
# 190      1
# 108      1
# 120      1
# 111      1
# 195      1
# 235      1
# 147      1
# Name: count, dtype: int64

# %%
sns.displot(df['PPI'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['PPI'],y=df['Price'])
plt.show()

# %%
df.drop(columns=['Inches','xres','yres'],inplace=True)

# %%
sns.displot(df['Price'],kde=True)
plt.xticks(np.arange(0,550000,50000),rotation=90)
plt.show()

# %%
sns.displot(x=np.log(df['Price']),kde=True)
plt.show()

# %%
np.log(df['Price'])
# Out:
# 0       11.740611
# 1       11.341639
# 2       10.894793
# 3       12.379332
# 4       12.037956
#           ...
# 1270    10.998761
# 1271    11.852970
# 1272     9.974132
# 1273    11.178990
# 1274    10.451204
# Name: Price, Length: 1224, dtype: float64

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram     Gpu       OpSys  Weight  Price  \
# 518      HP  Notebook  Intel Core i5    8  Nvidia  Windows 10    2.04  83326
#
#      Touchscreen  IPS  PPI
# 518            0    0  141

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.15,random_state=42)

# %%
x.shape
# Out:
# (1224, 10)

# %%
y.shape
# Out:
# (1224,)

# %%
x_train.shape
# Out:
# (1040, 10)

# %%
x_test.shape
# Out:
# (184, 10)

# %%
# !pip uninstall scikit-learn-y
# Out:
# WARNING: Skipping scikit-learn-y as it is not installed.

# %%
# !pip install scikit-learn

# %%
# !pip uninstall xbboost -y
# Out:
# WARNING: Skipping xbboost as it is not installed.

# %%
# !pip install xgboost

# %%
# !pip install --upgrade scikit-learn xgboost

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
x_train.columns
# Out:
# Index(['Company', 'TypeName', 'Cpu', 'Ram', 'Gpu', 'OpSys', 'Weight',
#        'Touchscreen', 'IPS', 'PPI'],
#       dtype='object')

# %%
x_train.sample()
# Out:
#     Company TypeName            Cpu  Ram     Gpu       OpSys  Weight  \
# 428      HP   Gaming  Intel Core i7   12  Nvidia  Windows 10    3.35
#
#      Touchscreen  IPS  PPI
# 428            0    0  127

# %%
# Linear Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=LinearRegression()

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7849856605264011
# MAE 0.20009131164138014
# MSE 0.06788986678247118

# %%
# Lasso
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=Lasso(alpha=0.001)

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7924906052301861
# MAE 0.19507719803626206
# MSE 0.06552021228688189

# %%
# Ridge
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=Ridge(alpha=10)

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7903099306180841
# MAE 0.1967045378886578
# MSE 0.06620875105724465

# %%
# KNeighborsRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=KNeighborsRegressor()

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7855292933844328
# MAE 0.19255016433664923
# MSE 0.06771821701064337

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=DecisionTreeRegressor(max_depth=8)

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8066585135130077
# MAE 0.1839863710479938
# MSE 0.06104675526879714

# %%
# SVR Support vector report
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=SVR(C=100000)

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8219001445666763
# MAE 0.17685077499359655
# MSE 0.05623427483463433

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=AdaBoostRegressor()

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.7975003413247947
# MAE 0.20319514088100607
# MSE 0.06393840933871114

# %%
# RandomForest
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=RandomForestRegressor()

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.8632629276547488
# MAE 0.15971777937890724
# MSE 0.0431741513076344

# %%
# # eXtreme GradientBoostingRegressor
# step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

# step2=XGBRegressor(n_estimators=50,max_depth=5)

# pipe=Pipeline([('step1',step1),('step2',step2)])
# pipe.fit(x_train,y_train)
# y_pred=pipe.predict(x_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))
# print('MSE',mean_squared_error(y_test,y_pred))


# Errors

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])],remainder='passthrough')

step2=GradientBoostingRegressor(n_estimators=490)

pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# R2 score 0.874170431701516
# MAE 0.14788813059759978
# MSE 0.039730153114410555

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install npx --quiet

# %%
# !npm install localtunnel --quiet
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 826ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠧

# %%
x_train.sample()
# Out:
#     Company TypeName            Cpu  Ram     Gpu       OpSys  Weight  \
# 894     MSI   Gaming  Intel Core i7   16  Nvidia  Windows 10    2.43
#
#      Touchscreen  IPS  PPI
# 894            0    1  255

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'MSI', 'Toshiba'],
#       dtype=object)

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD processor', 'Intel Core i3',
#        'Intel Core M', 'Intel Atom', 'Intel Celeron', 'Intel Pentium',
#        'Intel Xeon'], dtype=object)

# %%
df['PPI'].describe()
# Out:
# count    1224.000000
# mean      145.476307
# std        42.114912
# min        91.000000
# 25%       127.000000
# 50%       141.000000
# 75%       157.000000
# max       352.000000
# Name: PPI, dtype: float64

# %% [markdown]
# # New Section

# %%
# !pip install streamlit --quiet

# %%
# import streamlit as st
# import pickle
# import numpy as np
# import pandas as pd
# from sklearn.preprocessing import LabelEncoder

# # Import the model
# pipe = pickle.load(open('pipe.pkl', 'rb'))
# df = pickle.load(open('df.pkl', 'rb'))

# st.title('Laptop Price Predictor')

# # Brand
# company = st.selectbox('Brand', df['Company'].unique())

# # Type of laptop
# Type = st.selectbox('Type', df['TypeName'].unique())

# # CPU
# Cpu = st.selectbox('Processor', df['Cpu'].unique())

# # RAM
# Ram = st.selectbox('RAM (in GB)', [2, 4, 6, 8, 12, 16, 24, 32, 64])

# # GPU
# Gpu = st.selectbox('GPU', df['Gpu'].unique())

# # OS
# os = st.selectbox('Operating System', df['OpSys'].unique())

# # Weight
# Weight = st.number_input('Weight of the Laptop (in KG)', min_value=0.6, max_value=4.8, value=2.0, step=0.1)

# # Touchscreen
# Touchscreen = st.selectbox('Touchscreen', ['No', 'Yes'])

# # IPS
# IPS = st.selectbox('IPS', ['No', 'Yes'])

# # Screen size
# Screen_size = st.number_input('Screen Size (in Inches)', min_value=13.0, max_value=19.0, value=14.0, step=0.1)

# # Resolution
# Resolution = st.selectbox('Screen Resolution', ['1920x1080', '1366x768', '1600x900', '3840x2160', '3200x1800', '2160x1440', '2880x1800', '2560x1600', '2560x1440', '2304x1440'])

# if st.button('Predict Price'):
#     # Convert categorical variables to numerical
#     Touchscreen = 1 if Touchscreen == 'Yes' else 0
#     IPS = 1 if IPS == 'Yes' else 0

#     # Calculate PPI
#     xres = int(Resolution.split('x')[0])
#     yres = int(Resolution.split('x')[1])
#     ppi = ((xres**2) + (yres**2))**0.5 / Screen_size

#     # Create a DataFrame for the input
#     query = pd.DataFrame([[company, Type, Cpu, Ram, Gpu, os, Weight, Touchscreen, IPS, ppi]],
#                          columns=['Company', 'TypeName', 'Cpu', 'Ram', 'Gpu', 'OpSys', 'Weight', 'Touchscreen', 'IPS', 'PPI'])

#     # Encode categorical variables
#     for col in ['Company', 'TypeName', 'Cpu', 'Gpu', 'OpSys']:
#         le = LabelEncoder()
#         le.fit(df[col])
#         query[col] = le.transform(query[col])

#     # Predict the price
#     predicted_price = np.exp(pipe.predict(query))
#     st.subheader(f"The Predicted Price of this Laptop is ₹{int(predicted_price[0])}")

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# import the model
pipe=pickle.load(open('pipe.pkl','rb'))
df=pickle.load(open('df.pkl','rb'))

st.title('Laptop Price Predictor')
# brand
company=st.selectbox('Brand',df['Company'].unique())
# type of laptop
Type=st.selectbox('Type',df['TypeName'].unique())
# cpu
Cpu=st.selectbox('Processor',df['Cpu'].unique())
# Ram
Ram=st.selectbox('RAM (in GB)',[2,4,6,8,12,16,24,32,64])
# gpu
Gpu=st.selectbox('GPU',df['Gpu'].unique())
# os
os=st.selectbox('Operating System',df['OpSys'].unique())
# weight
Weight=st.number_input('Weight of the Laptop (in KG)',min_value=0.6,max_value=4.8,value=2.0,step=0.1)
# Touchscreen
Touchscreen=st.selectbox('Touchscreen',['No','Yes'])
# IPS
IPS=st.selectbox('IPS',['No','Yes'])
# screen size
Screen_size=st.number_input('Screen Size (in Inches)',min_value=13.0,max_value=19.0,value=14.0,step=0.1)
# Resolution
Resolution=st.selectbox('Screen Resolution',['1920x1080','1366x768','1600x900','3840x2160','3200x1800','2160x1440','2880x1800','2560x1600','2560x1440','2304x1440'])
#
if st.button('Predict Price'):
  ppi=None
  if Touchscreen=='Yes':
    Touchscreen=1
  else:
    Touchscreen=0

  if IPS=='Yes':
    IPS=1
  else:
    IPS=0
  xres=int(Resolution.split('x')[0])
  yres=int(Resolution.split('x')[1])
  ppi=((xres**2)+(yres**2))**0.5/Screen_size
  query=np.array([[company,Type,Cpu,Ram,Gpu,os,Weight,Touchscreen,IPS,ppi]])
  # op=np.exp(pipe.predict(query))
  # st.subheader("The Predicted Price of this Laptop is ₹"+str(int(op[0])))

  op=np.exp(pipe.predict(query)[0])
  st.title(f'The Predicted Price of this Laptop is Rs.{op:.2f}')
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.148.64.69:8501
#
# your url is: https://lemon-books-lie.loca.lt
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
# ...
